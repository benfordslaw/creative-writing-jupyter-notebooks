# %% [markdown]
# ## Love Letter To-Do List Generator

# %% [markdown]
# Original by Christopher Strachey, written for the Manchester Mark I in 1952. [Read more here](https://grandtextauto.soe.ucsc.edu/2005/08/01/christopher-strachey-first-digital-artist/).
#
# Vocabulary based on [this implementation](https://github.com/gingerbeardman/loveletter/blob/master/index.php) in addition to [dariusk's corpora](https://github.com/dariusk/corpora).

# %%
names = ['benford', 'benny', 'ben', 'benji', 'bennamin', 'ben', 'benfy', 'benjamin', 'ben ford']

# %%
import json

with open ('encouraging_words.json', 'r') as input_file:
    adjs = json.load(input_file)['encouraging_words']

# %%
with open ('firstNames.json', 'r') as input_file:
    first_names = json.load(input_file)['firstNames']

# %%
activities = []

with open ('atus_activities.json', 'r') as input_file:
    input_json = json.load(input_file)['categories']
    for category in input_json:
        if 'examples' in category:
            activities += (category['examples'])

# %%
nouns = [
    'adoration',
    'affection',
    'ambition',
    'appetite',
    'ardour',
    'being',
    'burning',
    'charm',
    'craving',
    'desire',
    'devotion',
    'eagerness',
    'enchantment',
    'enthusiasm',
    'fancy',
    'fellow feeling',
    'fervour',
    'fondness',
    'heart',
    'hunger',
    'infatuation',
    'little liking',
    'longing',
    'love',
    'lust',
    'passion',
    'rapture',
    'sympathy',
    'thirst',
    'wish',
    'yearning'
]

# %%
with open ('adverbs.json', 'r') as input_file:
    advs = json.load(input_file)['adverbs']

# %%
verbs = [
    'adores',
    'attracts',
    'clings to',
    'holds dear',
    'hopes for',
    'hungers for',
    'likes',
    'longs for',
    'loves',
    'lusts after',
    'pants for',
    'pines for',
    'sighs for',
    'tempts',
    'thirsts for',
    'treasures',
    'yearns for',
    'woos'
]

# %%
with open ('interjections.json', 'r') as input_file:
    interj = json.load(input_file)['interjections']

# %%
# textwrap library used to "wrap" the text at a particular length
import textwrap
import random

# output begins with salutation
output = random.choice(names) + ",\n\n"

# creates a list of activities (pulled from a json of activities) and modifies each
# adds the modified list to the text
sender_activities = []
for i in range(random.randint(1,3)):
    temp_activity = random.choice(activities).split()
    for i in range(len(temp_activity)):
        if '/' in temp_activity[i]:
            temp_activity[i] = random.choice(temp_activity[i].split('/'))
        if '(' in temp_activity[i]:
            temp_activity[i-1] = temp_activity[i-1].replace('.', '')
            temp_activity = temp_activity[:i]
            break
        if 'hh' == temp_activity[i] or 'nonhh' == temp_activity[i]:
            temp_activity[i] = ""
            temp_activity[i+1] = random.choice(first_names)
    sender_activities.append(' '.join(temp_activity))
output += textwrap.fill("i'm out " + ' and '.join(sender_activities) + '.', 60) + '\n\n'

# inside this loop, build the phrases. strachey implemented "short" phrases
# and "long" phrases; two or more "short" phrases in a row have special
# formatting rules, so we need to know what the last phrase kind was in
# order to generate the output.
history = []
body = ""
for i in range(5):
    kind = random.choice(["short", "long"])
    if kind == "long":
        # similar to above, creates and modifies an activity to add to the sentence
        recip_activity = random.choice(activities).split()
        for i in range(len(recip_activity)):
            if '/' in recip_activity[i]:
                recip_activity[i] = random.choice(recip_activity[i].split('/'))
            recip_activity[i] = recip_activity[i].replace('ing', 'ed')
            if '(' in recip_activity[i]:
                recip_activity[i-1] = recip_activity[i-1].replace('.', '')
                recip_activity = recip_activity[:i]
                break
            if 'hh' == recip_activity[i] or 'nonhh' == recip_activity[i]:
                recip_activity[i] = ""
                recip_activity[i+1] = random.choice(first_names)
        # adjectives and adverbs will be present only 50% of the time
        line = " ".join([
            "you'd be my",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns),
            random.choice([random.choice(advs), ""]),
            'which',
            random.choice(verbs),
            "your",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns),
            'if you ' + ' '.join(recip_activity),
            random.choice(["while i" + random.choice(["'m gone", "'m away", "'m out"]), 
                           "before i" + random.choice(["'m back", "'m home", 
                                                       " see you again", " get back", " get home"])])])
        body += random.choice([random.choice(interj) + ', ', '']) + line
    else:
        adj_noun = random.choice(adjs) + " " + random.choice(nouns)
        # if the last phrase was "short," use truncated form
        if len(history) > 0 and history[-1] == "short":
            body += ": my " + adj_noun
        else:
            body += "you'd be my " + adj_noun
    body += ". "
    history.append(kind)
# clean up output
body = body.replace("  ", " ")
body = body.replace(". :", ":")
# put everything together
output += textwrap.fill(body, 60)
output += "\n\nyours " + random.choice(advs) + ",\n"
output += random.choice(first_names)
print(output.lower())
# Out:
# ben,
#
# i'm out waiting for the barber and stretching and dropping
# ava off at senior center.
#
# you'd be my brilliant craving. curses, you'd be my fellow
# feeling which thirsts for your wonderful wish if you talked
# with the camp counselor while i'm away. you'd be my
# excellent rapture justly which clings to your impressive
# adoration if you cared for an orphaned animal before i'm
# home. you'd be my excellent infatuation. you'd be my
# sympathy which likes your enchantment if you talked with
# insurance agents while i'm away.
#
# yours generally,
# alondra
#
#
# ben,
#
# i'm out attending plays.
#
# you'd be my heavenly fancy: my heavenly ardour: my wondrous
# enthusiasm. nah, you'd be my thoughtful affection faithfully
# which attracts your sympathy if you doed stress management
# exercises before i'm home. come on, you'd be my heavenly
# heart angrily which woos your miraculous eagerness if you
# readed to or with gabrielle before i see you again.
#
# yours solidly,
# jack
#
#
# benford,
#
# i'm out buying books items and watching a stock car race and
# getting crabbing license.
#
# you'd be my lifechanging sympathy: my thoughtful charm: my
# beautiful adoration. see ya, you'd be my thoughtful
# enthusiasm rigidly which woos your electrifying heart if you
# signed for certified mail before i get home. you'd be my
# cool sympathy which pines for your remarkable devotion if
# you donated money while i'm away.
#
# yours upward,
# isaac
#
#
# bennamin,
#
# i'm out phone calls from customers and roller-skating.
#
# you'd be my affection which hungers for your fabulous
# rapture if you watched wiffle ball before i see you again.
# nuts, you'd be my awesome lust smoothly which likes your
# yearning if you cryed before i'm back. hallelujah, you'd be
# my lifechanging rapture which pants for your sweet affection
# if you used computer to pay bills before i'm home. you'd be
# my skillful adoration. you'd be my marvelous fancy gently
# you dropped off peyton at soccer practice while i'm away.
#
# yours mechanically,
# gage
#
#
# benji,
#
# i'm out attending the county fair and building a shed.
#
# you'd be my bravo devotion which adores your lust if you
# sweeped steps before i'm back. drat, you'd be my eagerness
# which pants for your passion if you repaired toys before i
# see you again. you'd be my genius wish. you'd be my
# innovative enthusiasm mechanically which tempts your bravo
# enthusiasm if you raked leaves before i get back. you'd be
# my cool yearning which hopes for your thoughtful rapture if
# you taked self-defense while i'm out.
#
# yours limply,
# aubrey
#
#
# bennamin,
#
# i'm out watching water aerobics and setting up a manger and
# checking out adult care facility.
#
# you'd be my legendary devotion. tsk, you'd be my enthusiasm
# which hopes for your ardour if you replaced fuses before i
# get back. you'd be my fantastic hunger: my kind lust. you'd
# be my kind hunger not which clings to your magical sympathy
# if you changed clothes before i get home.
#
# yours immediately,
# eva
#
#
# bennamin,
#
# i'm out cleaning refrigerator and planning household menu.
#
# you'd be my electrifying fervour: my powerful fervour: my
# impressive rapture: my magical thirst: my magical fondness.
#
# yours commonly,
# ella
#
#
# ben,
#
# i'm out gargling mouthwash.
#
# you'd be my kind desire: my cool eagerness: my wondrous
# craving: my delightful charm. you'd be my being which longs
# for your burning if you hugged neighbors while i'm gone.
#
# yours kookily,
# owen
#
#
# benford,
#
# i'm out observing  kaleb class and meeting with landscaper
# and passing through metal detector.
#
# you'd be my thoughtful burning. no way, you'd be my fancy
# which loves your love if you taked academic class before i
# get home. you'd be my perfect fervour keenly which attracts
# your exciting eagerness if you car accident before i get
# back. you'd be my innovative desire: my fantastic heart.
#
# yours yieldingly,
# lilly
#
#
# benford,
#
# i'm out putting away outside toys.
#
# g'day, you'd be my charm which pines for your beautiful love
# if you donated clothed before i get back. you'd be my
# enchanting appetite. you'd be my bravo passion which
# attracts your charm if you talked with leah before i get
# home. you'd be my beautiful enthusiasm: my impressive
# yearning.
#
# yours far,
# kendall
#
#
# ben,
#
# i'm out installing a trailer hitch and shooting league.
#
# you'd be my marvelous heart. humbug, you'd be my fondness
# rapidly which lusts after your cool fondness if you attended
# study group while i'm gone. you'd be my ardour quickly which
# attracts your heart if you rock climbed while i'm out. you'd
# be my groundbreaking lust tremendously which holds dear your
# powerful being if you organized closet for margaret while
# i'm gone. you'd be my perfect heart.
#
# yours unaccountably,
# savannah
#
#
# ben,
#
# i'm out helping  eric get into car and home schooling a
# jayden and attending  cristian back-to-school night.
#
# you'd be my eagerness jaggedly which likes your rapture if
# you distributed groceries at food bank before i see you
# again. hmm, you'd be my enchantment only which longs for
# your fancy if you putted up "for sale" signs for house
# before i get home. you'd be my marvelous enthusiasm: my
# impressive ambition: my heavenly yearning.
#
# yours suddenly,
# natalie
#
#
# benji,
#
# i'm out setting up a manger and doing environmental clean-
# up.
#
# you'd be my lovely desire. you'd be my enchanting fellow
# feeling unabashedly which clings to your ardour if you
# overhauled engine while i'm out. oho, you'd be my miraculous
# being which loves your little liking if you talked with a
# loan officer while i'm away. you'd be my breathtaking wish.
# you'd be my rapture jaggedly which lusts after your terrific
# rapture if you putted katelyn to bed before i'm back.
#
# yours greatly,
# adam
#
#
# benjamin,
#
# i'm out cleaning up after pets and checking phone messages
# and waking  laura.
#
# you'd be my wondrous fervour physically which lusts after
# your enthusiasm if you cleaned parks before i get home.
# you'd be my fondness which pants for your congratulations
# craving if you checked wesley homework before i get back.
# you'd be my perfect infatuation: my phenomenal fondness: my
# remarkable affection.
#
# yours broadly,
# francisco
#
#
# ben,
#
# i'm out filling out job application.
#
# oy, you'd be my fancy which tempts your remarkable passion
# if you passed through metal detector before i see you again.
# you'd be my enchanting love. sssh, you'd be my cool yearning
# obediently which sighs for your lust if you dryed dishes
# before i see you again. you'd be my impressive wish
# coaxingly which loves your masterful longing if you putted
# new roof on house while i'm out. you'd be my lifechanging
# desire.
#
# yours ferociously,
# edwin
#
#
# ben,
#
# i'm out doing own hair and discus.
#
# you bet, you'd be my lovely hunger which yearns for your
# kind little liking if you filed nails before i get home.
# you'd be my masterful passion fully which tempts your charm
# if you heared confession before i get home. you'd be my
# rejuvenating ardour jubilantly which loves your lovely
# hunger if you artistic painted before i get home. gah, you'd
# be my hunger weakly which woos your kind being if you waited
# in line at the bank before i'm back. alas, you'd be my
# terrific fondness delightfully which loves your rapture if
# you loaded software on computer while i'm out.
#
# yours deceivingly,
# evan
#
#
# ben,
#
# i'm out helping w for  kiara and maintaining smoke
# detectors.
#
# you'd be my elegant thirst. you'd be my kind appetite
# knottily which likes your awesome charm if you talked to
# telephone repairperson while i'm out. you'd be my miraculous
# yearning: my congratulations rapture. is it, you'd be my
# stunning fondness which yearns for your ambition if you
# shopped at mall before i get back.
#
# yours politely,
# dalton
#
#
# benny,
#
# i'm out supporting racers and speed walking.
#
# you'd be my amazing devotion. fiddle-dee-dee, you'd be my
# miraculous heart repeatedly which treasures your ardour if
# you gived jocelyn a bottle before i'm back. you'd be my
# wonderful burning longingly which holds dear your enchanting
# thirst if you sended out resumes before i get home. you'd be
# my amazing thirst: my thoughtful appetite.
#
# yours adventurously,
# aubrey
#
#
# ben,
#
# i'm out leading bible study.
#
# you'd be my marvelous charm. you'd be my yearning which
# attracts your kind enchantment if you calf roped while i'm
# out. you'd be my miraculous burning. you'd be my lust
# seemingly which loves your appetite if you played lacrosse
# while i'm away. you'd be my excellent devotion unaccountably
# which likes your fondness if you listened to podcast before
# i'm home.
#
# yours suddenly,
# christopher
#
#
# benjamin,
#
# i'm out raising money for political candidates and instant
# messaging and home schooling a  alexis.
#
# you'd be my desire often which hungers for your perfect
# ardour if you travel emergency while i'm away. you'd be my
# fantastic enchantment. duh, you'd be my sweet appetite
# energetically which likes your masterful adoration if you
# re-shelved library books before i get back. you'd be my
